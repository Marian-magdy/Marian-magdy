# %% [markdown]
# <a href="https://colab.research.google.com/github/Marian-magdy/Marian-magdy/blob/main/4_tasks%20%26feature%20engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas._libs.tslibs import dtypes
#identify numerical and categorical variables
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
from sklearn.model_selection import train_test_split
data = pd.read_csv('/content/drive/MyDrive/LoanExport.csv')
#28 columns 13 integr,14 object,1 float...now we want to know the unique values in each variable
data.nunique()
data['FirstTimeHomebuyer'].unique()
data['MonthsDelinquent'].unique()
import matplotlib.pyplot as plt
data['FirstTimeHomebuyer'].hist(bins=20)
data['MonthsDelinquent'].hist(bins=20)
data['NumBorrowers'].unique()
data['NumBorrowers'].hist(bins=20)
data['CreditScore'].unique()
data['OrigInterestRate'].hist(bins=20)    #import csv,handling missing ,duplicates
data.describe()
#quantify missing data& make bar plot
data.isnull().sum()
data.isnull().mean()
#data.isnull().sum().plot.bar(figsize=(12,3))
##plt.xlabel('Variables')
#plt.ylabel('Percentage of missing values')
#plt.title('Quantifying_missing_data')
#now seller name contain 241000 missing data wit ,08 mean percent ,now we will determine cardinality in categorical values
data.nunique().sort_values
data['EverDelinquent'].unique()
data['NumBorrowers'].unique()
data['LoanPurpose'].unique()
data['PropertyType'].unique()
data['PPM'].unique()
data['Channel'].unique()
data['Occupancy'].unique()
data['Units'].unique()
data['FirstTimeHomebuyer'].unique()
data.nunique().plot.bar(figsize=(12,10))
plt.xlabel('Variables')
plt.ylabel('Number of Unique Categories')
plt.title('Cardinality')
#identify rare categories in categorical values
label_frequency = data['FirstTimeHomebuyer'].value_counts()/ len(data)
print(label_frequency)
label_frequency = data['Units'].value_counts()/ len(data)
print(label_frequency)
label_frequency = data['Occupancy'].value_counts()/ len(data)
print(label_frequency)
label_frequency = data['PPM'].value_counts()/ len(data)
print(label_frequency)
label_frequency = data['PropertyType'].value_counts()/ len(data)
print(label_frequency)
label_frequency = data['NumBorrowers'].value_counts()/ len(data)
print(label_frequency)
label_frequency = data['EverDelinquent'].value_counts()/ len(data)
print(label_frequency)
#first time home buyer 3   'N', 'X', 'Y       N    0.631852
                                            # X    0.267678
                                            # Y    0.100470
#units 5              1, 2, 4, 3, 0]        1    0.979918
                                           # 2    0.016092
                                           # 3    0.002014(rare)
                                           # 4    0.001969(rare)
                                          #  0    0.000007(rare)
#occupancy 3          'O', 'I', 'S'         O    0.947435
                                          #  I    0.029967
                                           # S    0.022597
#channel 4            T', 'R', 'C', 'B'       T    0.575294
                                            # R    0.422778
                                            #C    0.001396(rare)
                                            #B    0.000532(rare)
#ppm 3                N', 'X', 'Y'          N    0.968001
                                          #   X    0.018545
                                           #  Y    0.013453
#product type 1         FRM 
#property type  7      SF', 'PU', 'CO', 'MH', 'CP', 'LH', 'X    SF    0.840357
                                                            #  PU    0.094376
                                                            #  CO    0.062103
                                                             # MH    0.002481
                                                             # LH    0.000360(R)
                                                             # CP    0.000247(r)
                                                             #  X     0.000075(r)
#loan purpose 3       P,N,C                               P    0.423413
                                                       #   N    0.377545
                                                       #   C    0.199042
#num borrowers 3      1,2,x                             2     0.642767
                                               #         1     0.356070
                                                #        X     0.001163(rare)
#everdelinquet 2      0,1                           0    0.802152
                                                   # 1    0.197848     
#check for duplicate   no duplicate
duplicate = data.duplicated()
print(duplicate.sum())
data[duplicate]
#distinguishing numerical variables distribution(most of the data skewed except DTI,origin UBP,interest rate,months in repayment)
data.hist(bins=30, figsize=(12,12), density=True)
plt.show
#handling outliers
sns.boxplot(y = data['CreditScore'])
plt.title('boxplot')
def find_boundaries (df, variable, distance) :
  IQR = df[variable].quantile(0.75) - df[variable].quantile(0.25)
  lower_boundary = df[variable].quantile(0.25) - (IQR * distance)
  upper_boundary = df[variable].quantile(0.75) + (IQR * distance)
  return upper_boundary, lower_boundary
upper_boundary, lower_boundary = find_boundaries(data, 'CreditScore', 1.5)
upper_boundary, lower_boundary
#(870.0, 558.0)  those values below and above are outliers,now we will 
outliers = np.where(data['CreditScore'] > upper_boundary,True,
           np.where(data['CreditScore'] < lower_boundary,True, False))
outliers_df = data.loc[outliers, 'CreditScore']
outliers_df.head()
#so here outlier is 5 in the top 5 rows of the outlier list
outliers_df.unique() #and here is all the list of the outliers in the credit score variable
#comparing feature magnitude
data.describe()
#imputing missing data,drop seller name column and drop  x in first time home borrowe
data.isnull().sum()
#task 1 :delete seller name
del data['SellerName']
data.head()
#task 2 :CReddit score,replace 0 with mean
data['CreditScore']=data['CreditScore'].replace(0,data['CreditScore'].mean())
data['CreditScore'].unique()
print(data)
#task 3 :CS 2 data['CreditScore']
data['CS2'] = pd.cut(data['CreditScore'], bins=[0, 650, 700, 750, 900 ], labels=['poor', 'fair', 'good', 'excellent'])
data['CS2']
#
data.head
# task 4 
data['LTV']
data['LTV2'] = pd.cut(data['LTV'], bins=[ 0, 25, 50, 100 ], labels=['low', 'medium', 'high'])
data['LTV2']
#task 5 :months to years 
data['MonthsInRepayment']
data['YearInRepayment'] = pd.cut(data['MonthsInRepayment'], bins=[ 0, 48, 96, 144, 192, 240 ], labels=['0-4', '4-8', '8-12', '12-16', '16-20'])
data['YearInRepayment']
#TAsk 5; drop values x in column Firsttime home buyer
import pandas as pd
index_to_be_deleted = data[data['FirstTimeHomebuyer'] == 'X' ].index
print(index_to_be_deleted)
data.drop(index_to_be_deleted,inplace=True)
data.head()
data['FirstTimeHomebuyer'].unique()
#[213436 rows x 30 columns]> now.
#data["EverDelinquent"] = data["EverDelinquent"].map({"+": 1, "-": 0})
data.rename(columns={"EverDelinquent": "target"}, inplace=True)
cat_cols = [
    c for c in data.columns if data[c].dtypes=="O"]
num_cols = [
    c for c in data.columns if data[c].dtypes!= "O"]
data.to_csv("MM.csv", index=False)
data = pd.read_csv("MM.csv")
data.isnull().sum()
data["CS2"].unique()
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
label_encoder =LabelEncoder()
data['FirstTimeHomebuyer']= label_encoder.fit_transform(data['FirstTimeHomebuyer'])
data['FirstTimeHomebuyer'].dtype
data['MSA']= label_encoder.fit_transform(data['MSA'])
data['Occupancy']= label_encoder.fit_transform(data['Occupancy'])
data['Channel']= label_encoder.fit_transform(data['Channel'])
data['PPM']= label_encoder.fit_transform(data['PPM'])
data['ProductType']= label_encoder.fit_transform(data['ProductType'])
data['PropertyState']= label_encoder.fit_transform(data['PropertyState'])
data['PropertyType']= label_encoder.fit_transform(data['PropertyType'])
data['LoanSeqNum']= label_encoder.fit_transform(data['LoanSeqNum'])
data['CS2']= label_encoder.fit_transform(data['CS2'])
data['LTV2']= label_encoder.fit_transform(data['LTV2'])
data['YearInRepayment']= label_encoder.fit_transform(data['YearInRepayment'])
data['LoanPurpose']= label_encoder.fit_transform(data['LoanPurpose'])
data['NumBorrowers']= label_encoder.fit_transform(data['NumBorrowers'])
data.isnull().sum()
data['ServicerName']= label_encoder.fit_transform(data['ServicerName'])
data['PostalCode'].dtype
data = data.astype({'PostalCode':'string'})
data['PostalCode']= label_encoder.fit_transform(data['PostalCode'])
#mutual information
plt.style.use("seaborn-whitegrid")
#from sklearn.feature_selection import mutual_info_classif

sns.heatmap(data[['PostalCode', 'ServicerName', 'NumBorrowers', 'LoanPurpose']].corr(), cmap='Blues', annot=True)
plt.show()
#linear regression PPM.1,yearin repaymentt.2
from sklearn.linear_model import LinearRegression
X=data[['PPM']]
y=data.target
#Creating a Simple Linear Regression Model to predict salaries
lm=LinearRegression()
lm.fit(X,y)
#Prediction of salaries by the model
yp=lm.predict(X)
print(yp)
from sklearn.linear_model import LinearRegression
X=data[['YearInRepayment']]
y=data.target
#Creating a Simple Linear Regression Model to predict salaries
lm=LinearRegression()
lm.fit(X,y)
#Prediction of salaries by the model
yp=lm.predict(X)
print(yp)
#plot the linear regression model ppm
from bokeh.plotting import figure, show, output_file
p=figure(title="Actual vs Predicted target", width=450, height=300)
p.title.align = 'center'
p.circle(data.PPM, data.target)
p.line(data.PPM, data.target, legend_label='everdelinquent', line_width=3, line_alpha=0.4)
p.circle(data.PPM, yp, color="red")
p.line(data.PPM,yp, color="red",legend_label='everdeliquent', line_width=3, line_alpha=0.4)
p.xaxis.axis_label = 'PPM'
p.yaxis.axis_label = 'delinquent'
show(p)
import numpy as np
print(f'Residuals: {y-yp}')
np.sqrt(np.mean(np.square(y-yp)))  #RMSE
np.mean(abs(y-yp))                 #MAE
#RMSE/MAE computation using sklearn library        MAE.3
from sklearn.metrics import mean_squared_error, mean_absolute_error
np.sqrt(mean_squared_error(y, yp))
mean_absolute_error(y, yp)
np.sqrt(np.mean(np.square(y-yp)))
np.mean(abs(y-yp))
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import mutual_info_classif

#Standardizing the features
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train, X_test, y_train, y_test = train_test_split(
 data.drop('target', axis=1), data['target'], test_size=0.3,
random_state=0)
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled = pd.DataFrame(X_train_scaled,columns=X_train.columns)
scaler.mean_
scaler.scale_
#Performing mean normalization
means = X_train.mean(axis=0)
means
ranges = X_train.max(axis=0)-X_train.min(axis=0)
ranges
X_train_scaled = (X_train - means) / ranges
X_test_scaled = (X_test - means) / ranges
#mutual info classif
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data.drop(labels=['target'], axis=1),
    data['target'],test_size=0.3,random_state=0)
from sklearn.feature_selection import mutual_info_classif
mutual_info = mutual_info_classif(X_train, y_train)
mutual_info
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)
#MonthsDelinquent      0.493850
#CS2                   0.037291
#CreditScore           0.034406
#MonthsInRepayment     0.029635
#using KBEST
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20, 8))
from sklearn.feature_selection import SelectKBest
sel_five_cols = SelectKBest(mutual_info_classif, k=5)
sel_five_cols.fit(X_train, y_train)
X_train.columns[sel_five_cols.get_support()]
#Index(['CreditScore', 'MonthsDelinquent', 'MonthsInRepayment', 'CS2',
       #'YearInRepayment'],
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
def score_dataset(X, y, model=XGBRegressor()):
  
    # Metric for Housing competition is RMSLE (Root Mean Squared Log Error)
    score = cross_val_score(
        model, X, y, cv=5, scoring="neg_mean_squared_log_error",
    )
    score = -1 * score.mean()
    score = np.sqrt(score)
    return score
score_dataset(X, y)     #0.2779752376670
data.info() 
#K-means discretization :months delinquent,Cs2,months repayment,loan term,units    k means
from sklearn.preprocessing import KBinsDiscretizer
disc = KBinsDiscretizer(n_bins=10, encode='ordinal',
strategy='kmeans')
disc.fit(X_train[['MonthsDelinquent', 'CS2', 'YearInRepayment']])
disc.bin_edges_
train_t = disc.transform(X_train[['MonthsDelinquent', 'CS2', 'YearInRepayment']]
)
train_t = pd.DataFrame(train_t, columns = ['MonthsDelinquent', 'CS2',
                                           'YearInRepayment'])
print(train_t.head())
test_t = disc.transform(X_test[['MonthsDelinquent', 'CS2', 'YearInRepayment']])
test_t = pd.DataFrame(test_t, columns = ['MonthsDelinquent', 'CS2',
                                         'YearInRepayment'])
score_dataset(X, y)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# N    0.631852
# X    0.267678
# Y    0.100470
# Name: FirstTimeHomebuyer, dtype: float64
# 1    0.979918
# 2    0.016092
# 3    0.002014
# 4    0.001969
# 0    0.000007
# Name: Units, dtype: float64
# O    0.947435
# I    0.029967
# S    0.022597
# Name: Occupancy, dtype: float64
# N    0.968001
# X    0.018545
# Y    0.013453
# Name: PPM, dtype: float64
# SF    0.840357
# PU    0.094376
# CO    0.062103
# MH    0.002481
# LH    0.000360
# CP    0.000247
# X     0.000075
# Name: PropertyType, dtype: float64
# 2     0.642767
# 1     0.356070
# X     0.001163
# Name: NumBorrowers, dtype: float64
# 0    0.802152
# 1    0.197848
# Name: EverDelinquent, dtype: float64
# 0
#         CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  \
# ...
